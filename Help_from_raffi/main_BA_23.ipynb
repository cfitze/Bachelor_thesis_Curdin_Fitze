# %%
import pandas as pd

df = pd.read_excel("./BA_23FS_Curdin_Fitze_5_7_9_11_13_TSextract.xlsx", sheet_name="15min")


# %matplotlib tk

columns = df.columns.tolist()

datasets = df[columns].keys()  # Get the available datasets

print("columns: {}".format(columns))
print("datasets: {}".format(datasets))

options=[{'label': column, 'value': column} for column in columns]

print("options: {}".format(columns))
# Out:
# columns: ['DateTime', 'Solar [kWh]', 'SelfConsumption [kWh]', 'Demand [kWh]', 'Net Grid Import/Export [kWh]', 'Battery [kWh]', 'Revenue', 'Savings', 'NetBenefit', 'TotalProduced', 'SolarToNet', 'Total Incident Radiation [MWh]', 'Solar DC [kWh]', 'PVTariff', 'Eprice']
# datasets: Index(['DateTime', 'Solar [kWh]', 'SelfConsumption [kWh]', 'Demand [kWh]',
#        'Net Grid Import/Export [kWh]', 'Battery [kWh]', 'Revenue', 'Savings',
#        'NetBenefit', 'TotalProduced', 'SolarToNet',
#        'Total Incident Radiation [MWh]', 'Solar DC [kWh]', 'PVTariff',
#        'Eprice'],
#       dtype='object')
# options: ['DateTime', 'Solar [kWh]', 'SelfConsumption [kWh]', 'Demand [kWh]', 'Net Grid Import/Export [kWh]', 'Battery [kWh]', 'Revenue', 'Savings', 'NetBenefit', 'TotalProduced', 'SolarToNet', 'Total Incident Radiation [MWh]', 'Solar DC [kWh]', 'PVTariff', 'Eprice']

# %%
df.describe()
# Out:
#         Solar [kWh]  SelfConsumption [kWh]  Demand [kWh]  \
# count  35037.000000           35037.000000  35037.000000
# mean       3.929687               1.575766      2.575057
# std        6.355488               1.936869      1.955545
# min       -0.025000               0.000000      0.524375
# 25%       -0.025000               0.000000      1.123750
# 50%       -0.025000               0.798750      1.743750
# 75%        5.498650               2.649989      3.822500
# max       25.000000              10.284375     12.767500
#
#        Net Grid Import/Export [kWh]  Battery [kWh]       Revenue  \
# count                  35037.000000   35037.000000  35037.000000
# mean                       2.319564       0.034358      0.422812
# std                        5.195723       1.749089      0.940304
# min                       -0.210484      -8.925040      0.000000
# 25%                       -0.025000       0.000000      0.000000
# ...

# %%
df.plot(x="DateTime", y="Solar [kWh]")
# Out:
# <Axes: xlabel='DateTime'>

# %%
dt = df["DateTime"].values
solar = df["Solar [kWh]"].values

# %%
import matplotlib.pyplot as plt

plt.plot(dt, solar)
